# %% [markdown]
# <a href="https://colab.research.google.com/github/garfield-gray/Calculations/blob/main/CalculationsPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# #PrevJunk

# %%
r6 = 6
r1 = 1
r2 = 2
l1 = 1j
c1 = -1j
r4 = 4
l21 = 2j
l22 = 2j
l4 = 4j

# %%
print(r6+l4)
# Out:
# (6+4j)

# %%
A = np.array([[-4, 4+2j],[16-4j, -8]])
b = np.array([8, -32]).T
V1 = np.linalg.solve(A, b)

# %%
V1
# Out:
# array([-1.93103448-0.82758621j, -0.27586207-0.68965517j])

# %%
A = np.array([[-4, 4+2j],[-2+1j, -2j]])
b = np.array([0, 12j]).T
V2 = np.linalg.solve(A, b)

# %%
V2
# Out:
# array([-0.87804878-4.09756098j, -2.34146341-2.92682927j])

# %%
V1[0]+V2[0]
# Out:
# (-2.8090832632464258-4.925147182506307j)

# %%
2*(-6-2j)/(2+1j)
# Out:
# (-5.6+0.8j)

# %%
A = np.array([[2, 0, 0, -1],
              [-2, 2, 2j, -2j],
              [0, 0, -1, 3],
              [0, 1, -1, 0]])
b = np.array([0, 0, 12, 6]).T
V = np.linalg.solve(A, b)
print(V)
# Out:
# [ 1.90243902+0.87804878j  5.41463415+5.26829268j -0.58536585+5.26829268j
#   3.80487805+1.75609756j]

# %%
A = np.array([[0, -1, 1],
              [-2, 2j, 1],
              [1, 1j, -1]])
b = np.array([4, -4, 0]).T
V = np.linalg.solve(A, b)
print(V)
# Out:
# [4.+0.j 0.+0.j 4.+0.j]

# %%
1e6/(500*333)
# Out:
# 6.006006006006006

# %%
100/16
# Out:
# 6.25

# %% [markdown]
# #Plot

# %%
import matplotlib.pyplot as plt

x = range(1, 1001)
y = [i**2 for i in x]
# plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x, y, c=y, cmap=plt.cm.Blues, s=10)
ax.ticklabel_format(style='plain')

# %%
from random import choice

class RandomWalk:
  """A class to generate random walks."""
  def __init__(self, num_points=5000):
    """Initialize attributes of a walk."""
    self.num_points = num_points
    # All walks start at (0, 0).
    self.x_values = [0]
    self.y_values = [0]
  def fill_walk(self):
    """Calculate all the points in the walk."""
    # Keep taking steps until the walk reaches the desired length.
    for i in range(self.num_points):
      # Decide which direction to go and how far to go in that direction.
      x_direction = choice([1, -1])
      x_distance = choice([0, 1, 2, 3, 4])
      x_step = x_direction * x_distance
      y_direction = choice([1, -1])
      y_distance = choice([0, 1, 2, 3, 4])
      y_step = y_direction * y_distance
      # Reject moves that go nowhere.
      if x_step == 0 and y_step == 0:
        continue

      # Calculate the new position.
      x = self.x_values[-1] + x_step
      y = self.y_values[-1] + y_step
      self.x_values.append(x)
      self.y_values.append(y)

# %%
import matplotlib.pyplot as plt
rw = RandomWalk(8_000)
rw.fill_walk()
#
# Plot the points in the walk.
plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, c=range(len(rw.y_values)), cmap = plt.cm.Blues, edgecolors='none',s=2)
ax.set_aspect('equal')
plt.show()

# %%
1_000_000
# Out:
# 1000000

# %%
# data collected from ncdc.noaa.gov
# Address of files
# %cd /content/drive/MyDrive/Uni/Algorithm
# !ls
# Out:
# /content/drive/MyDrive/Uni/Algorithm
# 3771126.csv
# CalculationsPractice.ipynb
# DynamicProg.ipynb
# GraphHw810898059.gdoc
# Introduction.to.Algorithms.4th.Leiserson.Stein.Rivest.Cormen.MIT.Press.9780262046305.EBooksWorld.ir.pdf
# opensource

# %%
# prompt: using pandas read the "3771126.csv" and show the head

import pandas as pd
df = pd.read_csv('3771126.csv')
df.head()
# Out:
#        STATION                               NAME  LATITUDE  LONGITUDE  \
# 0  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 1  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 2  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 3  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 4  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
#
#    ELEVATION        DATE  TAVG  TMAX  TMIN
# 0      127.5  2024-01-01   NaN  18.3   7.8
# 1      127.5  2024-01-02   NaN  18.3   5.6
# 2      127.5  2024-01-03   NaN  15.6   9.4
# 3      127.5  2024-01-04   NaN  16.7   5.0
# 4      127.5  2024-01-05   NaN  18.9   5.0

# %%
df
# Out:
#          STATION                               NAME  LATITUDE  LONGITUDE  \
# 0    USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 1    USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 2    USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 3    USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 4    USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# ..           ...                                ...       ...        ...
# 215  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 216  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 217  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 218  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
# 219  USW00003131  SAN DIEGO MONTGOMERY FIELD, CA US  32.81453 -117.13747
#
#      ELEVATION        DATE  TAVG  TMAX  TMIN
# 0        127.5  2024-01-01   NaN  18.3   7.8
# 1        127.5  2024-01-02   NaN  18.3   5.6
# 2        127.5  2024-01-03   NaN  15.6   9.4
# 3        127.5  2024-01-04   NaN  16.7   5.0
# 4        127.5  2024-01-05   NaN  18.9   5.0
# ..         ...         ...   ...   ...   ...
# 215      127.5  2024-08-03   NaN  31.1  18.9
# 216      127.5  2024-08-04   NaN  31.7  18.9
# 217      127.5  2024-08-05   NaN  31.1  19.4
# 218      127.5  2024-08-06   NaN  29.4  19.4
# 219      127.5  2024-08-07   NaN  27.2  20.0
#
# [220 rows x 9 columns]

# %%
# !ls
# Out:
# 2.5_day.geojson
# 3771126.csv
# CalculationsPractice.ipynb
# DynamicProg.ipynb
# eq_data_1_day_m1.geojson
# GraphHw810898059.gdoc
# Introduction.to.Algorithms.4th.Leiserson.Stein.Rivest.Cormen.MIT.Press.9780262046305.EBooksWorld.ir.pdf
# opensource

# %%
# prompt: read "eq_data_1_day_m1.geojson" and print a portion of it with indentation

import json

with open('2.5_day.geojson') as f:
  data = json.load(f)

# print(json.dumps(data['features'][:5], indent=2))
data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1723458158000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Day',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 24},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.54,
#     'place': '5 km NNW of Pinnacles, CA',
#     'time': 1723457888730,
#     'updated': 1723458086560,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75047587',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75047587.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 99,
#     'net': 'nc',
#     'code': '75047587',
#     'ids': ',nc75047587,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#     'nst': 42,
#     'dmin': 0.1047,
#     'rms': 0.12,
#     'gap': 55,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 5 km NNW of Pinnacles, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.17, 36.57, 5.13]},
#    'id': 'nc75047587'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '232 km SE of Chiniak, Alaska',
#     'time': 1723443919016,
#     'updated': 1723451265040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njk1',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njk1.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'us',
#     'code': '6000njk1',
#     'ids': ',us6000njk1,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': 2.332,
#     'rms': 0.42,
#     'gap': 232,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 232 km SE of Chiniak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4662, 56.1967, 10]},
#    'id': 'us6000njk1'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '17 km SSW of Fasā, Iran',
#     'time': 1723443156835,
#     'updated': 1723454166040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000njjz',
#     'ids': ',us6000njjz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 46,
#     'dmin': 4.51,
#     'rms': 0.69,
#     'gap': 60,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 17 km SSW of Fasā, Iran'},
#    'geometry': {'type': 'Point', 'coordinates': [53.5583, 28.8029, 10]},
#    'id': 'us6000njjz'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '5 km NW of Big Bear Lake, CA',
#     'time': 1723442066440,
#     'updated': 1723454589667,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40698271',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40698271.geojson',
#     'felt': 21,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 131,
#     'net': 'ci',
#     'code': '40698271',
#     'ids': ',ci40698271,',
#     'sources': ',ci,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 118,
#     'dmin': 0.02489,
#     'rms': 0.17,
#     'gap': 36,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5 km NW of Big Bear Lake, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.946, 34.2758333, 2.39]},
#    'id': 'ci40698271'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.78,
#     'place': '1 km NNE of Guayanilla, Puerto Rico',
#     'time': 1723439203720,
#     'updated': 1723439870620,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71457288',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71457288.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 119,
#     'net': 'pr',
#     'code': '71457288',
#     'ids': ',pr71457288,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.01648,
#     'rms': 0.22,
#     'gap': 116,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 1 km NNE of Guayanilla, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.7828333333333, 18.0343333333333, 16.3]},
#    'id': 'pr71457288'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '111 km SSE of Honchō, Japan',
#     'time': 1723438995045,
#     'updated': 1723455137351,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjt.geojson',
#     'felt': 15,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 301,
#     'net': 'us',
#     'code': '6000njjt',
#     'ids': ',us6000njjt,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.858,
#     'rms': 1.16,
#     'gap': 134,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 111 km SSE of Honchō, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [143.2832, 41.1617, 35]},
#    'id': 'us6000njjt'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '185 km NNE of Yakutat, Alaska',
#     'time': 1723437375776,
#     'updated': 1723438985040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '6000njjq',
#     'ids': ',us6000njjq,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 0.808,
#     'rms': 0.93,
#     'gap': 116,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 185 km NNE of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-139.0077, 61.1691, 2.457]},
#    'id': 'us6000njjq'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.55,
#     'place': '25 km NW of Grapevine, CA',
#     'time': 1723433023290,
#     'updated': 1723438842172,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40698159',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40698159.geojson',
#     'felt': 1,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 100,
#     'net': 'ci',
#     'code': '40698159',
#     'ids': ',ci40698159,us6000njjl,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 59,
#     'dmin': 0.05121,
#     'rms': 0.27,
#     'gap': 30,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 25 km NW of Grapevine, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.1233333, 35.0983333, 2.64]},
#    'id': 'ci40698159'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '80 km WSW of Tobelo, Indonesia',
#     'time': 1723432077553,
#     'updated': 1723435278040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjk',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjk.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000njjk',
#     'ids': ',us6000njjk,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 0.753,
#     'rms': 0.39,
#     'gap': 109,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 80 km WSW of Tobelo, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [127.3093, 1.5282, 140.245]},
#    'id': 'us6000njjk'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': 'Greenland Sea',
#     'time': 1723424915097,
#     'updated': 1723430832040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '6000njjf',
#     'ids': ',us6000njjf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 236,
#     'dmin': 3.979,
#     'rms': 0.36,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - Greenland Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [8.3371, 74.6936, 10]},
#    'id': 'us6000njjf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '45 km ENE of Estique, Peru',
#     'time': 1723422984248,
#     'updated': 1723423675040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjd',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjd.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000njjd',
#     'ids': ',us6000njjd,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.878,
#     'rms': 0.91,
#     'gap': 188,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 45 km ENE of Estique, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.5951, -17.4557, 176.168]},
#    'id': 'us6000njjd'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '6 km W of Laytonville, CA',
#     'time': 1723419307760,
#     'updated': 1723425993950,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75047422',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75047422.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'nc',
#     'code': '75047422',
#     'ids': ',nc75047422,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 33,
#     'dmin': 0.03132,
#     'rms': 0.15,
#     'gap': 94,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 6 km W of Laytonville, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-123.55, 39.67, 0.18]},
#    'id': 'nc75047422'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '3 km N of Yeranos, Armenia',
#     'time': 1723413760943,
#     'updated': 1723420280813,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njix',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njix.geojson',
#     'felt': 6,
#     'cdi': 7.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 276,
#     'net': 'us',
#     'code': '6000njix',
#     'ids': ',us6000njix,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 46,
#     'dmin': 0.354,
#     'rms': 0.86,
#     'gap': 37,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 3 km N of Yeranos, Armenia'},
#    'geometry': {'type': 'Point', 'coordinates': [45.1891, 40.2342, 1.452]},
#    'id': 'us6000njix'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '23 km SW of Lamont, CA',
#     'time': 1723413620270,
#     'updated': 1723418522040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40697927',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40697927.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'ci',
#     'code': '40697927',
#     'ids': ',ci40697927,us6000njiw,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 66,
#     'dmin': 0.04881,
#     'rms': 0.29,
#     'gap': 21,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 23 km SW of Lamont, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.0856667, 35.1075, 7.66]},
#    'id': 'ci40697927'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': 'Fiji region',
#     'time': 1723412758343,
#     'updated': 1723429115328,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njiv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njiv.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000njiv',
#     'ids': ',us6000njiv,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 49,
#     'dmin': 3.097,
#     'rms': 0.69,
#     'gap': 75,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - Fiji region'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.644, -19.0765, 569.598]},
#    'id': 'us6000njiv'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.69,
#     'place': '86 km NE of Punta Cana, Dominican Republic',
#     'time': 1723403322250,
#     'updated': 1723405786416,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024224002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024224002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 209,
#     'net': 'pr',
#     'code': '2024224002',
#     'ids': ',us6000njih,pr2024224002,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.9747,
#     'rms': 0.33,
#     'gap': 210,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 86 km NE of Punta Cana, Dominican Republic'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.8258, 19.1305, 90]},
#    'id': 'pr2024224002'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '34 km SW of Cantwell, Alaska',
#     'time': 1723402065391,
#     'updated': 1723402687040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aardpnv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aardpnv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '024aardpnv',
#     'ids': ',us6000njif,ak024aardpnv,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.59,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 34 km SW of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4537, 63.178, 10.7]},
#    'id': 'ak024aardpnv'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '27 km SSE of Denali National Park, Alaska',
#     'time': 1723401965298,
#     'updated': 1723402464040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aardevj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aardevj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'ak',
#     'code': '024aardevj',
#     'ids': ',us6000njie,ak024aardevj,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.86,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 27 km SSE of Denali National Park, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.4983, 63.3138, 0]},
#    'id': 'ak024aardevj'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '113 km E of Chignik, Alaska',
#     'time': 1723400507736,
#     'updated': 1723414167785,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aar8573',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aar8573.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.025,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'ak',
#     'code': '024aar8573',
#     'ids': ',us6000njib,ak024aar8573,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.53,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 113 km E of Chignik, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-156.6106, 56.5001, 64.8]},
#    'id': 'ak024aar8573'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '22 km NW of Grapevine, CA',
#     'time': 1723397634180,
#     'updated': 1723404557170,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40697623',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40697623.geojson',
#     'felt': 9,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 140,
#     'net': 'ci',
#     'code': '40697623',
#     'ids': ',ci40697623,us6000nji6,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 64,
#     'dmin': 0.02949,
#     'rms': 0.27,
#     'gap': 22,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 22 km NW of Grapevine, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.0913333, 35.0875, 13.99]},
#    'id': 'ci40697623'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': 'Fiji region',
#     'time': 1723395308170,
#     'updated': 1723398167040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nji3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nji3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000nji3',
#     'ids': ',us6000nji3,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': 3.107,
#     'rms': 0.75,
#     'gap': 80,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - Fiji region'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-178.4904, -20.7057, 556.247]},
#    'id': 'us6000nji3'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '35 km WSW of Ovalle, Chile',
#     'time': 1723393277397,
#     'updated': 1723394335380,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njhw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njhw.geojson',
#     'felt': 1,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '6000njhw',
#     'ids': ',us6000njhw,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 63,
#     'dmin': 0.116,
#     'rms': 0.77,
#     'gap': 63,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 35 km WSW of Ovalle, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.5266, -30.7431, 67.008]},
#    'id': 'us6000njhw'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': 'Pagan region, Northern Mariana Islands',
#     'time': 1723380203740,
#     'updated': 1723445611701,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njha',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njha.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 416,
#     'net': 'us',
#     'code': '6000njha',
#     'ids': ',us6000njha,',
#     'sources': ',us,',
#     'types': ',oaf,origin,phase-data,',
#     'nst': 102,
#     'dmin': 3.411,
#     'rms': 1.07,
#     'gap': 53,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.2 - Pagan region, Northern Mariana Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [145.8294, 18.6705, 130.686]},
#    'id': 'us6000njha'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '35 km SE of Perryville, Alaska',
#     'time': 1723374524612,
#     'updated': 1723374641946,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aamzbfx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aamzbfx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'ak',
#     'code': '024aamzbfx',
#     'ids': ',ak024aamzbfx,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.62,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 35 km SE of Perryville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-158.8154, 55.6505, 36.4]},
#    'id': 'ak024aamzbfx'}],
#  'bbox': [-178.4904, -30.7431, 0, 145.8294, 74.6936, 569.598]}

# %%
all_eq_dicts = data['features']
print(len(all_eq_dicts))
# Out:
# 24

# %%
all_eq_dicts
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 2.54,
#    'place': '5 km NNW of Pinnacles, CA',
#    'time': 1723457888730,
#    'updated': 1723458086560,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75047587',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75047587.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 99,
#    'net': 'nc',
#    'code': '75047587',
#    'ids': ',nc75047587,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 42,
#    'dmin': 0.1047,
#    'rms': 0.12,
#    'gap': 55,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 5 km NNW of Pinnacles, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-121.17, 36.57, 5.13]},
#   'id': 'nc75047587'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.2,
#    'place': '232 km SE of Chiniak, Alaska',
#    'time': 1723443919016,
#    'updated': 1723451265040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njk1',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njk1.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 158,
#    'net': 'us',
#    'code': '6000njk1',
#    'ids': ',us6000njk1,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 45,
#    'dmin': 2.332,
#    'rms': 0.42,
#    'gap': 232,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.2 - 232 km SE of Chiniak, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.4662, 56.1967, 10]},
#   'id': 'us6000njk1'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.3,
#    'place': '17 km SSW of Fasā, Iran',
#    'time': 1723443156835,
#    'updated': 1723454166040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjz',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjz.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 284,
#    'net': 'us',
#    'code': '6000njjz',
#    'ids': ',us6000njjz,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 46,
#    'dmin': 4.51,
#    'rms': 0.69,
#    'gap': 60,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.3 - 17 km SSW of Fasā, Iran'},
#   'geometry': {'type': 'Point', 'coordinates': [53.5583, 28.8029, 10]},
#   'id': 'us6000njjz'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.83,
#    'place': '5 km NW of Big Bear Lake, CA',
#    'time': 1723442066440,
#    'updated': 1723454589667,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40698271',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40698271.geojson',
#    'felt': 21,
#    'cdi': 3.8,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 131,
#    'net': 'ci',
#    'code': '40698271',
#    'ids': ',ci40698271,',
#    'sources': ',ci,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 118,
#    'dmin': 0.02489,
#    'rms': 0.17,
#    'gap': 36,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 5 km NW of Big Bear Lake, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.946, 34.2758333, 2.39]},
#   'id': 'ci40698271'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.78,
#    'place': '1 km NNE of Guayanilla, Puerto Rico',
#    'time': 1723439203720,
#    'updated': 1723439870620,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71457288',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71457288.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 119,
#    'net': 'pr',
#    'code': '71457288',
#    'ids': ',pr71457288,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 22,
#    'dmin': 0.01648,
#    'rms': 0.22,
#    'gap': 116,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 1 km NNE of Guayanilla, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.7828333333333, 18.0343333333333, 16.3]},
#   'id': 'pr71457288'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '111 km SSE of Honchō, Japan',
#    'time': 1723438995045,
#    'updated': 1723455137351,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjt',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjt.geojson',
#    'felt': 15,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 301,
#    'net': 'us',
#    'code': '6000njjt',
#    'ids': ',us6000njjt,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 27,
#    'dmin': 0.858,
#    'rms': 1.16,
#    'gap': 134,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 111 km SSE of Honchō, Japan'},
#   'geometry': {'type': 'Point', 'coordinates': [143.2832, 41.1617, 35]},
#   'id': 'us6000njjt'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '185 km NNE of Yakutat, Alaska',
#    'time': 1723437375776,
#    'updated': 1723438985040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjq',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjq.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'us',
#    'code': '6000njjq',
#    'ids': ',us6000njjq,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 28,
#    'dmin': 0.808,
#    'rms': 0.93,
#    'gap': 116,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 185 km NNE of Yakutat, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-139.0077, 61.1691, 2.457]},
#   'id': 'us6000njjq'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.55,
#    'place': '25 km NW of Grapevine, CA',
#    'time': 1723433023290,
#    'updated': 1723438842172,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40698159',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40698159.geojson',
#    'felt': 1,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 100,
#    'net': 'ci',
#    'code': '40698159',
#    'ids': ',ci40698159,us6000njjl,',
#    'sources': ',ci,us,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 59,
#    'dmin': 0.05121,
#    'rms': 0.27,
#    'gap': 30,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 25 km NW of Grapevine, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.1233333, 35.0983333, 2.64]},
#   'id': 'ci40698159'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': '80 km WSW of Tobelo, Indonesia',
#    'time': 1723432077553,
#    'updated': 1723435278040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjk',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjk.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '6000njjk',
#    'ids': ',us6000njjk,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 35,
#    'dmin': 0.753,
#    'rms': 0.39,
#    'gap': 109,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - 80 km WSW of Tobelo, Indonesia'},
#   'geometry': {'type': 'Point', 'coordinates': [127.3093, 1.5282, 140.245]},
#   'id': 'us6000njjk'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.1,
#    'place': 'Greenland Sea',
#    'time': 1723424915097,
#    'updated': 1723430832040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjf',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjf.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 400,
#    'net': 'us',
#    'code': '6000njjf',
#    'ids': ',us6000njjf,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 236,
#    'dmin': 3.979,
#    'rms': 0.36,
#    'gap': 58,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.1 - Greenland Sea'},
#   'geometry': {'type': 'Point', 'coordinates': [8.3371, 74.6936, 10]},
#   'id': 'us6000njjf'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.2,
#    'place': '45 km ENE of Estique, Peru',
#    'time': 1723422984248,
#    'updated': 1723423675040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njjd',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njjd.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 271,
#    'net': 'us',
#    'code': '6000njjd',
#    'ids': ',us6000njjd,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.878,
#    'rms': 0.91,
#    'gap': 188,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.2 - 45 km ENE of Estique, Peru'},
#   'geometry': {'type': 'Point', 'coordinates': [-69.5951, -17.4557, 176.168]},
#   'id': 'us6000njjd'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '6 km W of Laytonville, CA',
#    'time': 1723419307760,
#    'updated': 1723425993950,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75047422',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75047422.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'nc',
#    'code': '75047422',
#    'ids': ',nc75047422,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 33,
#    'dmin': 0.03132,
#    'rms': 0.15,
#    'gap': 94,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 6 km W of Laytonville, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-123.55, 39.67, 0.18]},
#   'id': 'nc75047422'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.2,
#    'place': '3 km N of Yeranos, Armenia',
#    'time': 1723413760943,
#    'updated': 1723420280813,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njix',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njix.geojson',
#    'felt': 6,
#    'cdi': 7.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 276,
#    'net': 'us',
#    'code': '6000njix',
#    'ids': ',us6000njix,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 46,
#    'dmin': 0.354,
#    'rms': 0.86,
#    'gap': 37,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.2 - 3 km N of Yeranos, Armenia'},
#   'geometry': {'type': 'Point', 'coordinates': [45.1891, 40.2342, 1.452]},
#   'id': 'us6000njix'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.74,
#    'place': '23 km SW of Lamont, CA',
#    'time': 1723413620270,
#    'updated': 1723418522040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40697927',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40697927.geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 116,
#    'net': 'ci',
#    'code': '40697927',
#    'ids': ',ci40697927,us6000njiw,',
#    'sources': ',ci,us,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 66,
#    'dmin': 0.04881,
#    'rms': 0.29,
#    'gap': 21,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.7 - 23 km SW of Lamont, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-119.0856667, 35.1075, 7.66]},
#   'id': 'ci40697927'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': 'Fiji region',
#    'time': 1723412758343,
#    'updated': 1723429115328,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njiv',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njiv.geojson',
#    'felt': 1,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '6000njiv',
#    'ids': ',us6000njiv,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 49,
#    'dmin': 3.097,
#    'rms': 0.69,
#    'gap': 75,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - Fiji region'},
#   'geometry': {'type': 'Point', 'coordinates': [-177.644, -19.0765, 569.598]},
#   'id': 'us6000njiv'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.69,
#    'place': '86 km NE of Punta Cana, Dominican Republic',
#    'time': 1723403322250,
#    'updated': 1723405786416,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024224002',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024224002.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 209,
#    'net': 'pr',
#    'code': '2024224002',
#    'ids': ',us6000njih,pr2024224002,',
#    'sources': ',us,pr,',
#    'types': ',origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.9747,
#    'rms': 0.33,
#    'gap': 210,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.7 - 86 km NE of Punta Cana, Dominican Republic'},
#   'geometry': {'type': 'Point', 'coordinates': [-67.8258, 19.1305, 90]},
#   'id': 'pr2024224002'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '34 km SW of Cantwell, Alaska',
#    'time': 1723402065391,
#    'updated': 1723402687040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aardpnv',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aardpnv.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'ak',
#    'code': '024aardpnv',
#    'ids': ',us6000njif,ak024aardpnv,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.59,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 34 km SW of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.4537, 63.178, 10.7]},
#   'id': 'ak024aardpnv'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '27 km SSE of Denali National Park, Alaska',
#    'time': 1723401965298,
#    'updated': 1723402464040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aardevj',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aardevj.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'ak',
#    'code': '024aardevj',
#    'ids': ',us6000njie,ak024aardevj,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.86,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 27 km SSE of Denali National Park, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.4983, 63.3138, 0]},
#   'id': 'ak024aardevj'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.2,
#    'place': '113 km E of Chignik, Alaska',
#    'time': 1723400507736,
#    'updated': 1723414167785,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aar8573',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aar8573.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': 3.025,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 158,
#    'net': 'ak',
#    'code': '024aar8573',
#    'ids': ',us6000njib,ak024aar8573,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,shakemap,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.53,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.2 - 113 km E of Chignik, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-156.6106, 56.5001, 64.8]},
#   'id': 'ak024aar8573'},
#  {'type': 'Feature',
#   'properties': {'mag': 3,
#    'place': '22 km NW of Grapevine, CA',
#    'time': 1723397634180,
#    'updated': 1723404557170,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40697623',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40697623.geojson',
#    'felt': 9,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 140,
#    'net': 'ci',
#    'code': '40697623',
#    'ids': ',ci40697623,us6000nji6,',
#    'sources': ',ci,us,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 64,
#    'dmin': 0.02949,
#    'rms': 0.27,
#    'gap': 22,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.0 - 22 km NW of Grapevine, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-119.0913333, 35.0875, 13.99]},
#   'id': 'ci40697623'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.3,
#    'place': 'Fiji region',
#    'time': 1723395308170,
#    'updated': 1723398167040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nji3',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nji3.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 284,
#    'net': 'us',
#    'code': '6000nji3',
#    'ids': ',us6000nji3,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 21,
#    'dmin': 3.107,
#    'rms': 0.75,
#    'gap': 80,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.3 - Fiji region'},
#   'geometry': {'type': 'Point', 'coordinates': [-178.4904, -20.7057, 556.247]},
#   'id': 'us6000nji3'},
#  {'type': 'Feature',
#   'properties': {'mag': 5,
#    'place': '35 km WSW of Ovalle, Chile',
#    'time': 1723393277397,
#    'updated': 1723394335380,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njhw',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njhw.geojson',
#    'felt': 1,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 385,
#    'net': 'us',
#    'code': '6000njhw',
#    'ids': ',us6000njhw,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 63,
#    'dmin': 0.116,
#    'rms': 0.77,
#    'gap': 63,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.0 - 35 km WSW of Ovalle, Chile'},
#   'geometry': {'type': 'Point', 'coordinates': [-71.5266, -30.7431, 67.008]},
#   'id': 'us6000njhw'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.2,
#    'place': 'Pagan region, Northern Mariana Islands',
#    'time': 1723380203740,
#    'updated': 1723445611701,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000njha',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000njha.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 416,
#    'net': 'us',
#    'code': '6000njha',
#    'ids': ',us6000njha,',
#    'sources': ',us,',
#    'types': ',oaf,origin,phase-data,',
#    'nst': 102,
#    'dmin': 3.411,
#    'rms': 1.07,
#    'gap': 53,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.2 - Pagan region, Northern Mariana Islands'},
#   'geometry': {'type': 'Point', 'coordinates': [145.8294, 18.6705, 130.686]},
#   'id': 'us6000njha'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '35 km SE of Perryville, Alaska',
#    'time': 1723374524612,
#    'updated': 1723374641946,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024aamzbfx',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024aamzbfx.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'ak',
#    'code': '024aamzbfx',
#    'ids': ',ak024aamzbfx,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.62,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 35 km SE of Perryville, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-158.8154, 55.6505, 36.4]},
#   'id': 'ak024aamzbfx'}]

# %%
mags, lons, lats, eq_titles = [], [], [], []
for eq_dict in all_eq_dicts:
  mag = eq_dict['properties']['mag']

  lon = eq_dict['geometry']['coordinates'][0]
  lat = eq_dict['geometry']['coordinates'][1]
  eq_title = eq_dict['properties']['title']
  mags.append(mag)
  lons.append(lon)
  lats.append(lat)
  eq_titles.append(eq_title)

# %%
all_eq_dicts[4].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
all_eq_dicts[4]['properties']
# Out:
# {'mag': 2.78,
#  'place': '1 km NNE of Guayanilla, Puerto Rico',
#  'time': 1723439203720,
#  'updated': 1723439870620,
#  'tz': None,
#  'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71457288',
#  'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71457288.geojson',
#  'felt': None,
#  'cdi': None,
#  'mmi': None,
#  'alert': None,
#  'status': 'reviewed',
#  'tsunami': 0,
#  'sig': 119,
#  'net': 'pr',
#  'code': '71457288',
#  'ids': ',pr71457288,',
#  'sources': ',pr,',
#  'types': ',origin,phase-data,',
#  'nst': 22,
#  'dmin': 0.01648,
#  'rms': 0.22,
#  'gap': 116,
#  'magType': 'md',
#  'type': 'earthquake',
#  'title': 'M 2.8 - 1 km NNE of Guayanilla, Puerto Rico'}

# %%
  import plotly.express as px

# %%
title = 'Global Earthquakes'

fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,

color=mags,

color_continuous_scale='Viridis',

labels={'color':'Magnitude'},

projection='natural earth',
hover_name=eq_titles,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="087e90b7-5035-4299-a0ae-2ed6cf6b20df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("087e90b7-5035-4299-a0ae-2ed6cf6b20df")) {                    Plotly.newPlot(                        "087e90b7-5035-4299-a0ae-2ed6cf6b20df",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003esize=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cbr\u003eMagnitude=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["M 2.5 - 5 km NNW of Pinnacles, CA","M 3.2 - 232 km SE of Chiniak, Alaska","M 4.3 - 17 km SSW of Fas\u0101, Iran","M 2.8 - 5 km NW of Big Bear Lake, CA","M 2.8 - 1 km NNE of Guayanilla, Puerto Rico","M 4.4 - 111 km SSE of Honch\u014d, Japan","M 2.9 - 185 km NNE of Yakutat, Alaska","M 2.6 - 25 km NW of Grapevine, CA","M 4.5 - 80 km WSW of Tobelo, Indonesia","M 5.1 - Greenland Sea","M 4.2 - 45 km ENE of Estique, Peru","M 2.6 - 6 km W of Laytonville, CA","M 4.2 - 3 km N of Yeranos, Armenia","M 2.7 - 23 km SW of Lamont, CA","M 4.5 - Fiji region","M 3.7 - 86 km NE of Punta Cana, Dominican Republic","M 2.5 - 34 km SW of Cantwell, Alaska","M 2.6 - 27 km SSE of Denali National Park, Alaska","M 3.2 - 113 km E of Chignik, Alaska","M 3.0 - 22 km NW of Grapevine, CA","M 4.3 - Fiji region","M 5.0 - 35 km WSW of Ovalle, Chile","M 5.2 - Pagan region, Northern Mariana Islands","M 2.6 - 35 km SE of Perryville, Alaska"],"lat":[36.57,56.1967,28.8029,34.2758333,18.0343333333333,41.1617,61.1691,35.0983333,1.5282,74.6936,-17.4557,39.67,40.2342,35.1075,-19.0765,19.1305,63.178,63.3138,56.5001,35.0875,-20.7057,-30.7431,18.6705,55.6505],"legendgroup":"","lon":[-121.17,-149.4662,53.5583,-116.946,-66.7828333333333,143.2832,-139.0077,-119.1233333,127.3093,8.3371,-69.5951,-123.55,45.1891,-119.0856667,-177.644,-67.8258,-149.4537,-151.4983,-156.6106,-119.0913333,-178.4904,-71.5266,145.8294,-158.8154],"marker":{"color":[2.54,3.2,4.3,2.83,2.78,4.4,2.9,2.55,4.5,5.1,4.2,2.6,4.2,2.74,4.5,3.69,2.5,2.6,3.2,3.0,4.3,5.0,5.2,2.6],"coloraxis":"coloraxis","size":[2.54,3.2,4.3,2.83,2.78,4.4,2.9,2.55,4.5,5.1,4.2,2.6,4.2,2.74,4.5,3.69,2.5,2.6,3.2,3.0,4.3,5.0,5.2,2.6],"sizemode":"area","sizeref":0.013000000000000001,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"] ...

# %% [markdown]
# #API

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)

# %%
import requests
# Make an API call and check the response.
url = "https://api.github.com/search/repositories"
url += "?q=language:python+sort:stars+stars:>10000"
headers = {"Accept": "application/vnd.github.v3+json"}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")
# Out:
# Status code: 200

# %%
# Convert the response object to a dictionary.
response_dict = r.json()
# Process results.
print(response_dict.keys())
# Out:
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %%
response_dict['items'][2]
# Out:
# {'id': 21289110,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4OTExMA==',
#  'name': 'awesome-python',
#  'full_name': 'vinta/awesome-python',
#  'private': False,
#  'owner': {'login': 'vinta',
#   'id': 652070,
#   'node_id': 'MDQ6VXNlcjY1MjA3MA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/652070?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/vinta',
#   'html_url': 'https://github.com/vinta',
#   'followers_url': 'https://api.github.com/users/vinta/followers',
#   'following_url': 'https://api.github.com/users/vinta/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/vinta/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/vinta/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/vinta/subscriptions',
#   'organizations_url': 'https://api.github.com/users/vinta/orgs',
#   'repos_url': 'https://api.github.com/users/vinta/repos',
#   'events_url': 'https://api.github.com/users/vinta/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/vinta/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/vinta/awesome-python',
#  'description': 'An opinionated list of awesome Python frameworks, libraries, software and resources.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/vinta/awesome-python',
#  'forks_url': 'https://api.github.com/repos/vinta/awesome-python/forks',
#  'keys_url': 'https://api.github.com/repos/vinta/awesome-python/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/vinta/awesome-python/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/vinta/awesome-python/teams',
#  'hooks_url': 'https://api.github.com/repos/vinta/awesome-python/hooks',
#  'issue_events_url': 'https://api.github.com/repos/vinta/awesome-python/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/vinta/awesome-python/events',
#  'assignees_url': 'https://api.github.com/repos/vinta/awesome-python/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/vinta/awesome-python/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/vinta/awesome-python/tags',
#  'blobs_url': 'https://api.github.com/repos/vinta/awesome-python/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/vinta/awesome-python/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/vinta/awesome-python/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/vinta/awesome-python/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/vinta/awesome-python/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/vinta/awesome-python/languages',
#  'stargazers_url': 'https://api.github.com/repos/vinta/awesome-python/stargazers',
#  'contributors_url': 'https://api.github.com/repos/vinta/awesome-python/contributors',
#  'subscribers_url': 'https://api.github.com/repos/vinta/awesome-python/subscribers',
#  'subscription_url': 'https://api.github.com/repos/vinta/awesome-python/subscription',
#  'commits_url': 'https://api.github.com/repos/vinta/awesome-python/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/vinta/awesome-python/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/vinta/awesome-python/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/vinta/awesome-python/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/vinta/awesome-python/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/vinta/awesome-python/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/vinta/awesome-python/merges',
#  'archive_url': 'https://api.github.com/repos/vinta/awesome-python/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/vinta/awesome-python/downloads',
#  'issues_url': 'https://api.github.com/repos/vinta/awesome-python/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/vinta/awesome-python/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/vinta/awesome-python/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/vinta/awesome-python/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/vinta/awesome-python/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/vinta/awesome-python/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/vinta/awesome-python/deployments',
#  'created_at': '2014-06-27T21:00:06Z',
#  'updated_at': '2024-08-13T19:59:10Z',
#  'pushed_at': '2024-08-11T17:10:18Z',
#  'git_url': 'git://github.com/vinta/awesome-python.git',
#  'ssh_url': 'git@github.com:vinta/awesome-python.git',
#  'clone_url': 'https://github.com/vinta/awesome-python.git',
#  'svn_url': 'https://github.com/vinta/awesome-python',
#  'homepage': 'https://awesome-python.com/',
#  'size': 6769,
#  'stargazers_count': 215511,
#  'watchers_count': 215511,
#  'language': 'Python',
#  'has_issues': False,
#  'has_projects': False,
#  'has_downloads': True,
#  'has_wiki': False,
#  'has_pages': True,
#  'has_discussions': False,
#  'forks_count': 24733,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 417,
#  'license': {'key': 'other',
#   'name': 'Other',
#   'spdx_id': 'NOASSERTION',
#   'url': None,
#   'node_id': 'MDc6TGljZW5zZTA='},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': ['awesome',
#   'collections',
#   'python',
#   'python-framework',
#   'python-library',
#   'python-resources'],
#  'visibility': 'public',
#  'forks': 24733,
#  'open_issues': 417,
#  'watchers': 215511,
#  'default_branch': 'master',
#  'score': 1.0}

# %%
print(f"Total repositories: {response_dict['total_count']}")
print(f"Complete results: {not response_dict['incomplete_results']}")
# Explore information about the repositories.
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")
# Examine the first repository.
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
  print(key)
# Out:
# Total repositories: 525
# Complete results: True
# Repositories returned: 30
#
# Keys: 80
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# topics
# trees_url
# updated_at
# url
# visibility
# watchers
# watchers_count
# web_commit_signoff_required

# %%
print("\nSelected information about first repository:")
print(f"Name: {repo_dict['name']}")
print(f"Owner: {repo_dict['owner']['login']}")
print(f"Stars: {repo_dict['stargazers_count']}")
print(f"Repository: {repo_dict['html_url']}")
print(f"Created: {repo_dict['created_at']}")
print(f"Updated: {repo_dict['updated_at']}")
print(f"Description: {repo_dict['description']}")
# Out:
# Selected information about first repository:
# Name: youtube-dl
# Owner: ytdl-org
# Stars: 130690
# Repository: https://github.com/ytdl-org/youtube-dl
# Created: 2010-10-31T14:35:07Z
# Updated: 2024-08-13T18:47:57Z
# Description: Command-line program to download videos from YouTube.com and other video sites

# %%
import plotly.express as px
repo_names, stars, hover_texts = [], [], []
for repo_dict in repo_dicts:
  repo_names.append(repo_dict['name'])
  stars.append(repo_dict['stargazers_count'])
  owner = repo_dict['owner']['login']
  description = repo_dict['description']
  hover_text = f"{owner}<br />{description}"
  hover_texts.append(hover_text)
# Make visualization

title = "Most-Starred Python Projects on GitHub"
labels = {'x': 'Repository', 'y': 'Stars'}
fig = px.bar(x=repo_names, y=stars, title=title, labels=labels, hover_name=hover_texts)
fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
yaxis_title_font_size=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a4d354c3-8f04-4efd-9e5d-e16431693477" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4d354c3-8f04-4efd-9e5d-e16431693477")) {                    Plotly.newPlot(                        "a4d354c3-8f04-4efd-9e5d-e16431693477",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRepository=%{x}\u003cbr\u003eStars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["public-apis\u003cbr \u002f\u003eA collective list of free APIs","donnemartin\u003cbr \u002f\u003eLearn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.","vinta\u003cbr \u002f\u003eAn opinionated list of awesome Python frameworks, libraries, software and resources.","TheAlgorithms\u003cbr \u002f\u003eAll Algorithms implemented in Python","Significant-Gravitas\u003cbr \u002f\u003eAutoGPT is the vision of accessible AI for everyone, to use and to build on. Our mission is to provide the tools, so that you can focus on what matters.","jackfrued\u003cbr \u002f\u003ePython - 100\u5929\u4ece\u65b0\u624b\u5230\u5927\u5e08","AUTOMATIC1111\u003cbr \u002f\u003eStable Diffusion web UI","ytdl-org\u003cbr \u002f\u003eCommand-line program to download videos from YouTube.com and other video sites","huggingface\u003cbr \u002f\u003e\ud83e\udd17 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.","521xueweihan\u003cbr \u002f\u003e:octocat: \u5206\u4eab GitHub \u4e0a\u6709\u8da3\u3001\u5165\u95e8\u7ea7\u7684\u5f00\u6e90\u9879\u76ee\u3002Share interesting, entry-level open source projects on GitHub.","nvbn\u003cbr \u002f\u003eMagnificent app which corrects your previous console command.","pytorch\u003cbr \u002f\u003eTensors and Dynamic neural networks in Python with strong GPU acceleration","yt-dlp\u003cbr \u002f\u003eA feature-rich command-line audio\u002fvideo downloader","django\u003cbr \u002f\u003eThe Web framework for perfectionists with deadlines.","tensorflow\u003cbr \u002f\u003eModels and examples built with TensorFlow","fastapi\u003cbr \u002f\u003eFastAPI framework, high performance, easy to learn, fast to code, ready for production","home-assistant\u003cbr \u002f\u003e:house_with_garden: Open source home automation that puts local control and privacy first.","pallets\u003cbr \u002f\u003eThe Python micro framework for building web applications.","fighting41love\u003cbr \u002f\u003e\u4e2d\u82f1\u6587\u654f\u611f\u8bcd\u3001\u8bed\u8a00\u68c0\u6d4b\u3001\u4e2d\u5916\u624b\u673a\u002f\u7535\u8bdd\u5f52\u5c5e\u5730\u002f\u8fd0\u8425\u5546\u67e5\u8be2\u3001\u540d\u5b57\u63a8\u65ad\u6027\u522b\u3001\u624b\u673a\u53f7\u62bd\u53d6\u3001\u8eab\u4efd\u8bc1\u62bd\u53d6\u3001\u90ae\u7bb1\u62bd\u53d6\u3001\u4e2d\u65e5\u6587\u4eba\u540d\u5e93\u3001\u4e2d\u6587\u7f29\u5199\u5e93\u3001\u62c6\u5b57\u8bcd\u5178\u3001\u8bcd\u6c47\u60c5\u611f\u503c\u3001\u505c\u7528\u8bcd\u3001\u53cd\u52a8\u8bcd\u8868\u3001\u66b4\u6050\u8bcd\u8868\u3001\u7e41\u7b80\u4f53\u8f6c\u6362\u3001\u82f1\u6587\u6a21\u62df\u4e2d\u6587\u53d1\u97f3\u3001\u6c6a\u5cf0\u6b4c\u8bcd\u751f\u6210\u5668\u3001\u804c\u4e1a\u540d\u79f0\u8bcd\u5e93\u3001\u540c\u4e49\u8bcd\u5e93\u3001\u53cd\u4e49\u8bcd\u5e93\u3001\u5426\u5b9a\u8bcd\u5e93\u3001\u6c7d\u8f66\u54c1\u724c\u8bcd\u5e93\u3001\u6c7d\u8f66\u96f6\u4ef6\u8bcd\u5e93\u3001\u8fde\u7eed\u82f1\u6587\u5207\u5272\u3001\u5404\u79cd\u4e2d\u6587\u8bcd\u5411\u91cf\u3001\u516c\u53f8\u540d\u5b57\u5927\u5168\u3001\u53e4\u8bd7\u8bcd\u5e93\u3001IT\u8bcd\u5e93\u3001\u8d22\u7ecf\u8bcd\u5e93\u3001\u6210\u8bed\u8bcd\u5e93\u3001\u5730\u540d\u8bcd\u5e93\u3001\u5386\u53f2\u540d\u4eba\u8bcd\u5e93\u3001\u8bd7\u8bcd\u8bcd\u5e93\u3001 ...

# %%
import plotly.express as px
repo_links, stars, hover_texts = [], [], []
for repo_dict in repo_dicts:
  repo_name = repo_dict['name']

  repo_url = repo_dict['html_url']
  repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
  repo_links.append(repo_link)
  stars.append(repo_dict['stargazers_count'])
  owner = repo_dict['owner']['login']
  description = repo_dict['description']
  hover_text = f"{owner}<br />{description}"
  hover_texts.append(hover_text)
# Make visualization

title = "Most-Starred Python Projects on GitHub"
labels = {'x': 'Repository', 'y': 'Stars'}
fig = px.bar(x=repo_links, y=stars, title=title, labels=labels, hover_name=hover_texts)
fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
yaxis_title_font_size=20)
fig.update_traces(marker_color='SteelBlue', marker_opacity=0.6)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f367463b-f8e1-47b2-a57c-ec0fdb45a183" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f367463b-f8e1-47b2-a57c-ec0fdb45a183")) {                    Plotly.newPlot(                        "f367463b-f8e1-47b2-a57c-ec0fdb45a183",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRepository=%{x}\u003cbr\u003eStars=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["public-apis\u003cbr \u002f\u003eA collective list of free APIs","donnemartin\u003cbr \u002f\u003eLearn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.","vinta\u003cbr \u002f\u003eAn opinionated list of awesome Python frameworks, libraries, software and resources.","TheAlgorithms\u003cbr \u002f\u003eAll Algorithms implemented in Python","Significant-Gravitas\u003cbr \u002f\u003eAutoGPT is the vision of accessible AI for everyone, to use and to build on. Our mission is to provide the tools, so that you can focus on what matters.","jackfrued\u003cbr \u002f\u003ePython - 100\u5929\u4ece\u65b0\u624b\u5230\u5927\u5e08","AUTOMATIC1111\u003cbr \u002f\u003eStable Diffusion web UI","ytdl-org\u003cbr \u002f\u003eCommand-line program to download videos from YouTube.com and other video sites","huggingface\u003cbr \u002f\u003e\ud83e\udd17 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.","521xueweihan\u003cbr \u002f\u003e:octocat: \u5206\u4eab GitHub \u4e0a\u6709\u8da3\u3001\u5165\u95e8\u7ea7\u7684\u5f00\u6e90\u9879\u76ee\u3002Share interesting, entry-level open source projects on GitHub.","nvbn\u003cbr \u002f\u003eMagnificent app which corrects your previous console command.","pytorch\u003cbr \u002f\u003eTensors and Dynamic neural networks in Python with strong GPU acceleration","yt-dlp\u003cbr \u002f\u003eA feature-rich command-line audio\u002fvideo downloader","django\u003cbr \u002f\u003eThe Web framework for perfectionists with deadlines.","tensorflow\u003cbr \u002f\u003eModels and examples built with TensorFlow","fastapi\u003cbr \u002f\u003eFastAPI framework, high performance, easy to learn, fast to code, ready for production","home-assistant\u003cbr \u002f\u003e:house_with_garden: Open source home automation that puts local control and privacy first.","pallets\u003cbr \u002f\u003eThe Python micro framework for building web applications.","fighting41love\u003cbr \u002f\u003e\u4e2d\u82f1\u6587\u654f\u611f\u8bcd\u3001\u8bed\u8a00\u68c0\u6d4b\u3001\u4e2d\u5916\u624b\u673a\u002f\u7535\u8bdd\u5f52\u5c5e\u5730\u002f\u8fd0\u8425\u5546\u67e5\u8be2\u3001\u540d\u5b57\u63a8\u65ad\u6027\u522b\u3001\u624b\u673a\u53f7\u62bd\u53d6\u3001\u8eab\u4efd\u8bc1\u62bd\u53d6\u3001\u90ae\u7bb1\u62bd\u53d6\u3001\u4e2d\u65e5\u6587\u4eba\u540d\u5e93\u3001\u4e2d\u6587\u7f29\u5199\u5e93\u3001\u62c6\u5b57\u8bcd\u5178\u3001\u8bcd\u6c47\u60c5\u611f\u503c\u3001\u505c\u7528\u8bcd\u3001\u53cd\u52a8\u8bcd\u8868\u3001\u66b4\u6050\u8bcd\u8868\u3001\u7e41\u7b80\u4f53\u8f6c\u6362\u3001\u82f1\u6587\u6a21\u62df\u4e2d\u6587\u53d1\u97f3\u3001\u6c6a\u5cf0\u6b4c\u8bcd\u751f\u6210\u5668\u3001\u804c\u4e1a\u540d\u79f0\u8bcd\u5e93\u3001\u540c\u4e49\u8bcd\u5e93\u3001\u53cd\u4e49\u8bcd\u5e93\u3001\u5426\u5b9a\u8bcd\u5e93\u3001\u6c7d\u8f66\u54c1\u724c\u8bcd\u5e93\u3001\u6c7d\u8f66\u96f6\u4ef6\u8bcd\u5e93\u3001\u8fde\u7eed\u82f1\u6587\u5207\u5272\u3001\u5404\u79cd\u4e2d\u6587\u8bcd\u5411\u91cf\u3001\u516c\u53f8\u540d\u5b57\u5927\u5168\u3001\u53e4\u8bd7\u8bcd\u5e93\u3001IT\u8bcd\u5e93\u3001\u8d22\u7ecf\u8bcd\u5e93\u3001\u6210\u8bed\u8bcd\u5e93\u3001\u5730\u540d\u8bcd\u5e93\u3001\u5386\u53f2\u540d\u4eba\u8bcd\u5e93\u3001\u8bd7\u8bcd\u8bcd\u5e93\u3001 ...

# %%
repo_dicts[8]['html_url']
# Out:
# 'https://github.com/huggingface/transformers'

# %%
# gooleMap API

# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.7.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40716 sha256=9580e69c164cbd44ac7972e06bcfc3006ab566001b30f861f4ecbc163b5fba04
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
import googlemaps
import os

# %%
api_key = os.environ.get('AIzaSyBLiJJS-eqxKAn8_LbafK2C8cFdc0-vmRA')
gmaps = googlemaps.Client(key=api_key)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-091666adc1cd> in <cell line: 2>()
#       1 api_key = os.environ.get('AIzaSyBLiJJS-eqxKAn8_LbafK2C8cFdc0-vmRA')
# ----> 2 gmaps = googlemaps.Client(key=api_key)
#
# /usr/local/lib/python3.10/dist-packages/googlemaps/client.py in __init__(self, key, client_id, client_secret, timeout, connect_timeout, read_timeout, retry_timeout, requests_kwargs, queries_per_second, queries_per_minute, channel, retry_over_query_limit, experience_id, requests_session, base_url)
#     138         """
#     139         if not key and not (client_secret and client_id):
# --> 140             raise ValueError("Must provide API key or enterprise credentials "
#     141                              "when creating client.")
#     142
#
# ValueError: Must provide API key or enterprise credentials when creating client.

# %%
import requests

# Your Google Maps API key
API_KEY = 'AIzaSyBLiJJS-eqxKAn8_LbafK2C8cFdc0-vmRA'

# The address you want to geocode
address = "1600 Amphitheatre Parkway, Mountain View, CA"

# The endpoint for the Google Maps Geocoding API
endpoint = "https://maps.googleapis.com/maps/api/geocode/json"

# Define the parameters for the request
params = {
    "address": address,
    "key": API_KEY
}

# Make the request to the Google Maps API
response = requests.get(endpoint, params=params)

# Convert the response to JSON format
data = response.json()

# Print the response
if response.status_code == 200:
    # Extract the latitude and longitude from the response
    if data['status'] == 'OK':
        latitude = data['results'][0]['geometry']['location']['lat']
        longitude = data['results'][0]['geometry']['location']['lng']
        print(f"Address: {address}")
        print(f"Latitude: {latitude}")
        print(f"Longitude: {longitude}")
    else:
        print(f"Error: {data['status']}")
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Error: REQUEST_DENIED

# %%
import requests
import json
# Make an API call, and store the response.
url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
r = requests.get(url)
print(f"Status code: {r.status_code}")
# Explore the structure of the data.
response_dict = r.json()
response_string = json.dumps(response_dict, indent=4)
print(response_string)
# Out:
# Status code: 200
# {
#     "by": "sohkamyung",
#     "descendants": 307,
#     "id": 31353677,
#     "kids": [
#         31354987,
#         31354235,
#         31354040,
#         31358602,
#         31354201,
#         31354991,
#         31354315,
#         31353775,
#         31353925,
#         31354169,
#         31354273,
#         31354437,
#         31356902,
#         31358694,
#         31363418,
#         31353862,
#         31357186,
#         31356379,
#         31356826,
#         31355085,
#         31369435,
#         31357936,
#         31354142,
#         31354213,
#         31356311,
#         31357865,
#         31353929,
#         31364954,
#         31354621,
#         31356002,
#         31356407,
#         31355491,
#         31359235,
#         31356053,
#         31354347,
#         31355326,
#         31354703,
#         31353802
#     ],
#     "score": 786,
#     "time": 1652361401,
#     "title": "Astronomers reveal first image of the black hole at the heart of our galaxy",
#     "type": "story",
#     "url": "https://public.nrao.edu/news/astronomers-reveal-first-image-of-the-black-hole-at-the-heart-of-our-galaxy/"
# }

# %% [markdown]
# #Django

# %%
# just putting the cool code here:
